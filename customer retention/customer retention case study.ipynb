# %% [markdown]
# ###### E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.
# Be careful: There are two sheets (one is detailed) and second is encoded in the excel file. You may use any of them by extracting in separate excel sheet. The number of column(s) is more than 47. Read the column header carefully.
# Note : Data Scientists have to apply their analytical skills to give findings and conclusions in detailed data analysis written in jupyter notebook . Only data analysis is required.
# Need not to create machine learning models /but still if anybody comes with it that is welcome.
#
#
#
#
#
# Disclaimer:  The datasets and figure(s) are highly confidential. Any kind of commercial activities find with the content will be taken strict action. The dataset is only available for academic purpose.

# %%
#importing essential libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.preprocessing import StandardScaler,MinMaxScaler,power_transform
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import r2_score, mean_squared_error,accuracy_score,roc_auc_score,roc_curve,confusion_matrix,classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingClassifier
import warnings
warnings.filterwarnings('ignore')
from sklearn import preprocessing
import scipy.stats as stats
from scipy.stats import zscore
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB

# %%
fileName = r'file:///C:\Users\anand\Downloads\Customer_retention_dataset%20(1)\Customer_retention_dataset\customer_retention_dataset.xlsx'
df = pd.read_excel(fileName)

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df_code=pd.read_excel(r'C:\Users\anand\OneDrive\Documents\Book1.xlsx')

# %%
df_code
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
df_code.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
df_code.sample(4)
# Out:
#      1Gender of respondent  2 How old are you?   \
# 241                      1                    5
# 74                       1                    3
# 169                      1                    2
# 102                      1                    3
#
#     3 Which city do you shop online from?  \
# 241                              Gurgaon
# 74                                Karnal
# 169                                 Delhi
# 102                                 Solan
#
#      4 What is the Pin Code of where you shop online from?  \
# 241                                             122009
# 74                                              132001
# 169                                             110008
# 102                                             173212
#
#      5 Since How Long You are Shopping Online ?  \
# 241                                           1
# 74                                            5
# 169                                           5
# ...

# %%
type(df_code.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df_code.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
from string import digits

#Removing tab spaces
df_code.columns = df_code.columns.str.replace('\t','')

#Removing digits
remove_digits = str.maketrans('', '', digits)
df_code.columns = df_code.columns.str.translate(remove_digits)

#Removing leading and trailling spaces
df_code.columns = df_code.columns.str.strip()

# %%
df_code
# Out:
#      Gender of respondent  How old are you?  \
# 0                       0                 3
# 1                       1                 2
# 2                       1                 2
# 3                       0                 2
# 4                       1                 2
# ..                    ...               ...
# 264                     1                 2
# 265                     1                 3
# 266                     1                 4
# 267                     1                 1
# 268                     1                 4
#
#     Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# ..                                  ...
# 264                               Solan
# 265                           Ghaziabad
# 266                          Bangalore
# ...

# %% [markdown]
# ## Checking null values:

# %%
df_code.isnull()
# Out:
#      Gender of respondent  How old are you?  \
# 0                   False             False
# 1                   False             False
# 2                   False             False
# 3                   False             False
# 4                   False             False
# ..                    ...               ...
# 264                 False             False
# 265                 False             False
# 266                 False             False
# 267                 False             False
# 268                 False             False
#
#      Which city do you shop online from?  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ..                                   ...
# 264                                False
# 265                                False
# 266                                False
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df_code.isnull())
# Out:
# <AxesSubplot:>

# %%
df_code.isnull().sum().sum()
# Out:
# 0

# %%
df_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   Gender of respondent                                                                                     269 non-null    int64
#  1   How old are you?                                                                                         269 non-null    int64
#  2   Which city do you shop online from?                                                                      269 non-null    object
#  3   What is the Pin Code of where you shop online from?                                                      269 non-null    int64
# ...

# %% [markdown]
# ## Checking duplicate:

# %%
df_code.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 264     True
# 265     True
# 266     True
# 267     True
# 268     True
# Length: 269, dtype: bool

# %%
df_code.duplicated().sum()
# Out:
# 130

# %% [markdown]
# ### 130 duplicates are present

# %% [markdown]
# ## Removing duplicate:

# %%
df2=df_code.drop_duplicates()

# %%
df2
# Out:
#      Gender of respondent  How old are you?  \
# 0                       0                 3
# 1                       1                 2
# 2                       1                 2
# 3                       0                 2
# 4                       1                 2
# ..                    ...               ...
# 195                     0                 3
# 196                     0                 2
# 197                     0                 5
# 198                     0                 4
# 242                     1                 3
#
#     Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# ..                                  ...
# 195                               Noida
# 196                          Bangalore
# 197                               Noida
# ...

# %%
df2.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 242    False
# Length: 139, dtype: bool

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Now no duplicate are present

# %%
df2.columns
# Out:
# Index(['Gender of respondent', 'How old are you?',
#        'Which city do you shop online from?',
#        'What is the Pin Code of where you shop online from?',
#        'Since How Long You are Shopping Online ?',
#        'How many times you have made an online purchase in the past  year?',
#        'How do you access the internet while shopping on-line?',
#        'Which device do you use to access the online shopping?',
#        'What is the screen size of your mobile device?',
#        'What is the operating system (OS) of your device?',
#        'What browser do you run on your device to access the website?',
#        'Which channel did you follow to arrive at your favorite online store for the first time?',
#        'After first visit, how do you reach the online retail store?',
#        'How much time do you explore the e- retail store before making a purchase decision?',
#        'What is your preferred payment Option?',
# ...

# %%
df2.nunique()
# Out:
# Gender of respondent                                                     2
# How old are you?                                                         5
# Which city do you shop online from?                                     11
# What is the Pin Code of where you shop online from?                     39
# Since How Long You are Shopping Online ?                                 5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %% [markdown]
# # Univariate Analysis:

# %% [markdown]
# ## Visualisation:

# %%
personal_info=['Gender of respondent','How old are you?','Which city do you shop online from?',
               'What is the Pin Code of where you shop online from?','Since How Long You are Shopping Online ?',
                   'How many times you have made an online purchase in the past  year?']

# %%
for i in personal_info:
    if i!='What is the Pin Code of where you shop online from?':
        plt.figure(figsize=(8,6))
        df2[i].value_counts().plot.pie(autopct='%1.1f%%')
        centre=plt.Circle((0,0),0.7,fc='white')
        fig=plt.gcf()
        fig.gca().add_artist(centre)
        plt.xlabel(i)
        plt.ylabel('')
        plt.figure()

# %% [markdown]
# ## Analysis on the basis of Various following factors

# %%
#Resolving ambiguity of column 
#Changing 42 times and above to 41 times and above
df['How many times you have made an online purchase in the past  year?'].replace('42 times and above','41 times and above',
                                                                                inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.lineplot(df2['How many times you have made an online purchase in the past  year?'],
              df2['From the following, tick any (or all) of the online retailers you have shopped from;'])
# Out:
# <AxesSubplot:xlabel='How many times you have made an online purchase in the past  year?', ylabel='From the following, tick any (or all) of the online retailers you have shopped from;'>

# %% [markdown]
# ## Online Retailing:

# %%
plt.figure(figsize=(10,8))
sns.countplot(df2['Since How Long You are Shopping Online ?'],hue=df['How old are you?'])
# Out:
# <AxesSubplot:xlabel='Since How Long You are Shopping Online ?', ylabel='count'>

# %%
df2['Since How Long You are Shopping Online ?'].unique()
# Out:
# array([5, 4, 3, 1, 2], dtype=int64)

# %%
df2['Which city do you shop online from?'].unique()
# Out:
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.lineplot(df2['Which city do you shop online from?'],df2['Since How Long You are Shopping Online ?'],hue=df2['Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='Which city do you shop online from?', ylabel='Since How Long You are Shopping Online ?'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(df2['Since How Long You are Shopping Online ?'],
              hue=df2['After first visit, how do you reach the online retail store?'])
# Out:
# <AxesSubplot:xlabel='Since How Long You are Shopping Online ?', ylabel='count'>

# %%
for i in df2.columns[0:]:
    plt.figure()
    sns.scatterplot( x= df2[i], y= "Gender of respondent", data= df2)

# %%
plt.figure(figsize=(12,10))
sns.stripplot(df2['Why did you abandon the “Bag”, “Shopping Cart”?'],
              df2['From the following, tick any (or all) of the online retailers you have shopped from;'])
# Out:
# <AxesSubplot:xlabel='Why did you abandon the “Bag”, “Shopping Cart”?', ylabel='From the following, tick any (or all) of the online retailers you have shopped from;'>

# %% [markdown]
# ## descriptive statestics:

# %%
df2.describe()
# Out:
#        Gender of respondent  How old are you?  \
# count            139.000000        139.000000
# mean               0.625899          2.985612
# std                0.485640          1.028476
# min                0.000000          1.000000
# 25%                0.000000          2.000000
# 50%                1.000000          3.000000
# 75%                1.000000          4.000000
# max                1.000000          5.000000
#
#        What is the Pin Code of where you shop online from?  \
# count                                         139.000000
# mean                                       236059.913669
# std                                        153177.892485
# min                                        110008.000000
# 25%                                        132001.000000
# 50%                                        201306.000000
# 75%                                        202156.500000
# max                                        560037.000000
#
# ...

# %%
round(df2.describe().transpose(),2)
# Out:
#                                                     count       mean  \
# Gender of respondent                                139.0       0.63
# How old are you?                                    139.0       2.99
# What is the Pin Code of where you shop online f...  139.0  236059.91
# Since How Long You are Shopping Online ?            139.0       3.51
# How many times you have made an online purchase...  139.0       2.85
# How do you access the internet while shopping o...  139.0       3.84
# Which device do you use to access the online sh...  139.0       1.71
# What is the screen size of your mobile device?      139.0       4.24
# What is the operating system (OS) of your device?   139.0       1.81
# What browser do you run on your device to acces...  139.0       1.28
# Which channel did you follow to arrive at your ...  139.0       1.37
# After first visit, how do you reach the online ...  139.0       2.55
# How much time do you explore the e- retail stor...  139.0       3.94
# ...

# %%
plt.figure(figsize=(10,12))
sns.heatmap(round(df2.describe().transpose(),2),linewidth=2,annot=True,fmt="f")

plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# ## Correlation:

# %%
df2.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 3 Which city do you shop online from?                           -0.202451
# 6 How many times you have made an online purcha...               0.127210
# 7 How do you access the internet while shopping...              -0.089500
# 9 What is the screen size of your mobile device...              -0.035377
# 10 What is the operating system (OS) of your de...              -0.013198
# 11 What browser do you run on your device to ac...              -0.107140
# 12 Which channel did you follow to arrive at yo...              -0.165589
# 13 After first visit, how do you reach the onli...               0.016751
# 14 How much time do you explore the e- retail s...               0.103600
# 15 What is your preferred payment Option?\t\t\t...               0.003600
# 16 How 4 do you abandon (selecting an items and...               0.032194
# ...

# %%
plt.figure(figsize=(50,30))
sns.heatmap(df2.corr(),annot=True, linecolor='white',linewidths=.25)
# Out:
# <AxesSubplot:>

# %%
df2.columns
# Out:
# Index(['Gender of respondent', 'How old are you?',
#        'Which city do you shop online from?',
#        'What is the Pin Code of where you shop online from?',
#        'Since How Long You are Shopping Online ?',
#        'How many times you have made an online purchase in the past  year?',
#        'How do you access the internet while shopping on-line?',
#        'Which device do you use to access the online shopping?',
#        'What is the screen size of your mobile device?',
#        'What is the operating system (OS) of your device?',
#        'What browser do you run on your device to access the website?',
#        'Which channel did you follow to arrive at your favorite online store for the first time?',
#        'After first visit, how do you reach the online retail store?',
#        'How much time do you explore the e- retail store before making a purchase decision?',
#        'What is your preferred payment Option?',
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 0 to 242
# Data columns (total 71 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   Gender of respondent                                                                                     139 non-null    int64
#  1   How old are you?                                                                                         139 non-null    int64
#  2   Which city do you shop online from?                                                                      139 non-null    object
#  3   What is the Pin Code of where you shop online from?                                                      139 non-null    int64
# ...
